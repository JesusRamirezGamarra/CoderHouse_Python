# %%
#Termino1                 Termino
(34+6)*2
# Out:
# 80

# %%
(((23 + 3.66)-6.66 )/ 4 ) ** 3
# Out:
# 125.0

# %%
"Nico es!&$ un2312 profe horrible :("
# Out:
# 'Nico es!&$ un2312 profe horrible :('

# %%
#PRINT   <- comentario :) 


print(f"La edad de Nico es {23+9} :) --> {33 % 4} ")
# Out:
# La edad de Nico es 32 :) --> 1

# %%
#Variables!!!!!

# %% [markdown]
# ***Arrancamos con variables :) ***

# %%
#IMC   peso / altura al cuadrado en metros

#Cómo nombrar a las variables????
#1) Minuscula !!!!!
#2) todo en miniscula, menos la primer letra de la palabra 2 y 3 y 4 (camelCase)
#3) snakeCase


imc_de_nico = 87/ (1.81 ** 2)

# %%
print(f"El indice de masa corporal de Nico es: {imc_de_nico}")
# Out:
# El indice de masa corporal de Nico es: 26.555965935105768

# %%
imc_de_nico = 92

# %%
print(f"El indice de masa corporal de Nico es: {imc_de_nico}")
# Out:
# El indice de masa corporal de Nico es: 92

# %%
variableNueva = 11

# %%
variableNueva
# Out:
# 11

# %%
nombreProfe = "Nico Perez" #Ojo con las variables!!!

# %%
print(nombreProfe)
# Out:
# Nico Perez

# %%
datoEntrante = input()

# %%
datoEntrante
# Out:
# '10'

# %%
nombre = input("¿Cómo te llamas?")

# %%
nombre
# Out:
# 'Jesus'

# %%
nombre = int(   input("¿Qué edad tenes:  ?")    )

# %%
nombre
# Out:
# 38

# %%
altura = 1.83
peso = 87

# %%
imc = peso / (altura**2)

# %%
imc
# Out:
# 25.97867956642479

# %%
"Nico el profe" + "   Es horrible :( "
# Out:
# 'Nico el profe   Es horrible :( '

# %%
variableTexto = "Nico Profe Coder :("  #Pos arranca en cero

# %%
len(variableTexto)
# Out:
# 19

# %%
variableTexto[2:8]  #No cuenta al 8 -----  2<= x < 8
# Out:
# 'co Pro'

# %%
palabra = "Pithon"

# %%
palabra = "Python"

# %%
#palabra[1] = "y"

# %%
variableTexto[7:]
# Out:
# 'ofe Coder :('
